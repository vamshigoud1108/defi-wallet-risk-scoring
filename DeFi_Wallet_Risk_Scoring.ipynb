# %% [markdown]
# ## Problem Statement
# Given your experience working with the Aave V2 protocol, it's assumed that you have a clear understanding of lending protocols and on-chain transaction analysis.

# %% [markdown]
# #### NOTE:
# Using Covalent API to retrieve general Ethereum transactions for each wallet.

# %% [markdown]
# ### Importing required libraries

# %%
import pandas as pd
import requests
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Data Exploration
# - Wallet transaction data was retrieved using the **Covalent API**, which provides historical Ethereum transactions per wallet.
# - Only the wallet addresses given in the CSV were queried.
# - Each transaction is tagged with the wallet address for reference after flattening the API response.

# %%
# Loading Wallets
wallets_id = pd.read_csv('Wallet id - Sheet1.csv')
wallets_id
# Out:
#                                       wallet_id
# 0    0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 1    0x06b51c6882b27cb05e712185531c1f74996dd988
# 2    0x0795732aacc448030ef374374eaae57d2965c16c
# 3    0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9
# 4    0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae
# ..                                          ...
# 98   0xf60304b534f74977e159b2e159e135475c245526
# 99   0xf67e8e5805835465f7eba988259db882ab726800
# 100  0xf7aa5d0752cfcd41b0a5945867d619a80c405e52
# 101  0xf80a8b9cfff0febf49914c269fb8aead4a22f847
# 102  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
#
# [103 rows x 1 columns]

# %%
# Converting wallets to list
wallets_list = wallets_id['wallet_id'].tolist()
print(wallets_list[:5])
# Out:
# ['0x0039f22efb07a647557c7c5d17854cfd6d489ef3', '0x06b51c6882b27cb05e712185531c1f74996dd988', '0x0795732aacc448030ef374374eaae57d2965c16c', '0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9', '0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae']

# %% [markdown]
# #### Fetching the Transactions History from API

# %%
API_KEY = 'cqt_rQ7mB4WDDqgyTfhT6QxptKRyx8FF'

# %%
all_txns = []
for wallet in wallets_list:
    url = f"https://api.covalenthq.com/v1/1/address/{wallet}/transactions_v2/?key={API_KEY}"
    try:
        response = requests.get(url)
        data = response.json()
        txns = data["data"]["items"]
        for txn in txns:
            txn["wallet"] = wallet
            all_txns.append(txn)
    except Exception as e:
        print(f"Fetching Failed: {e}")

# %%
# Displaying raw transaction
all_txns[:1]
# Out:
# [{'block_signed_at': '2025-06-16T21:15:11Z',
#   'block_height': 22719696,
#   'block_hash': '0xff57a0c234e73c4897632e198caa0074e84d16080e0f99731a3da891faebb42b',
#   'tx_hash': '0x98703fb4a7c6804d82e98f009ecc0e089abd53de94696088fb9675dde740c570',
#   'tx_offset': 108,
#   'successful': True,
#   'miner_address': '0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5',
#   'from_address': '0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc',
#   'from_address_label': None,
#   'to_address': '0x13173761e24c3708495b1dd314920f67f97011d0',
#   'to_address_label': None,
#   'value': '0',
#   'value_quote': 0.0,
#   'pretty_value_quote': '$0.00',
#   'gas_metadata': {'contract_decimals': 18,
#    'contract_name': 'Ether',
#    'contract_ticker_symbol': 'ETH',
#    'contract_address': '0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee',
#    'supports_erc': None,
#    'logo_url': 'https://www.datocms-assets.com/86369/1669619533-ethereum.png'},
#   'gas_offered': 84929,
#   'gas_spent': 55815,
#   'gas_price': 4200000000,
#   'fees_paid': '234423000000000',
#   'gas_quote': 0.5993072070029296,
#   'pretty_gas_quote': '$0.60',
#   'gas_quote_rate': 2556.5205078125,
#   'log_events': [{'block_signed_at': '2025-06-16T21:15:11Z',
#     'block_height': 22719696,
#     'tx_offset': 108,
#     'log_offset': 369,
#     'tx_hash': '0x98703fb4a7c6804d82e98f009ecc0e089abd53de94696088fb9675dde740c570',
#     'raw_log_topics': ['0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
#      '0x000000000000000000000000c6b602de080fc9ac9d96a431b2d749d38e77cbbc',
#      '0x0000000000000000000000000039f22efb07a647557c7c5d17854cfd6d489ef3'],
#     'sender_contract_decimals': 9,
#     'sender_name': 'Free Roman Storm',
#     'sender_contract_ticker_symbol': 'FREEROMAN',
#     'sender_address': '0x13173761e24c3708495b1dd314920f67f97011d0',
#     'sender_address_label': None,
#     'sender_logo_url': 'https://logos.covalenthq.com/tokens/1/0x13173761e24c3708495b1dd314920f67f97011d0.png',
#     'supports_erc': ['erc20'],
#     'sender_factory_address': None,
#     'raw_log_data': '0x00000000000000000000000000000000000000000000000b671f8f0b5f8a8000',
#     'decoded': {'name': 'Transfer',
#      'signature': 'Transfer(indexed address from, indexed address to, uint256 value)',
#      'params': [{'name': 'from',
#        'type': 'address',
#        'indexed': True,
#        'decoded': True,
#        'value': '0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc'},
#       {'name': 'to',
#        'type': 'address',
#        'indexed': True,
#        'decoded': True,
#        'value': '0x0039f22efb07a647557c7c5d17854cfd6d489ef3'},
#       {'name': 'value',
#        'type': 'uint256',
#        'indexed': False,
#        'decoded': True,
#        'value': '210345000000000000000'}]}}],
#   'wallet': '0x0039f22efb07a647557c7c5d17854cfd6d489ef3'}]

# %%
# Converting 'all_txns' list to Dataframe
txns = pd.DataFrame(all_txns)
txns.head()
# Out:
#         block_signed_at  block_height  \
# 0  2025-06-16T21:15:11Z      22719696
# 1  2025-04-27T21:09:35Z      22362988
# 2  2025-03-24T23:27:47Z      22120041
# 3  2025-02-23T19:08:59Z      21911013
# 4  2025-02-11T03:05:11Z      21820480
#
#                                           block_hash  \
# 0  0xff57a0c234e73c4897632e198caa0074e84d16080e0f...
# 1  0xe8a130e1e7110fbdde7dd51e74d940f538057be01240...
# 2  0x893f17102836ef520b5239cf68595b7c02c78e206582...
# 3  0x016232bca14eaedba1297086544e1a24a3868ce8d40b...
# 4  0x385f706cfcfdf648c9196d4120011c354371bd1977db...
#
#                                              tx_hash  tx_offset  successful  \
# 0  0x98703fb4a7c6804d82e98f009ecc0e089abd53de9469...        108        True
# 1  0x0b8e89905717b9babd69aa7db6af0afb83331e9b8041...        131        True
# 2  0x5745f6d2e9397ed8ceb7120f42761e1f04643e132e94...        150        True
# 3  0x35cd404392ac9b7786bee78e4bfb2773cbb576b9c3dc...        107        True
# 4  0x51a4f04abaa498409b72d83b4365440f0738ac5bcca1...        196        True
#
#                                 miner_address  \
# 0  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 1  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 2  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 3  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 4  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
#
#                                  from_address from_address_label  \
# 0  0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc               None
# 1  0xfd0ce77ca6521e3cbbcfb07398cca8ec2648115d               None
# 2  0xc07aff7c831105bacaf2fb4d9506332112eee2a1               None
# 3  0xad38352c725c6768c11a9a71bc7d921a9355d56c               None
# 4  0x1e6971036be043c0e2457fe3f6dbed9f73354c6b               None
#
#                                    to_address  ...  \
# 0  0x13173761e24c3708495b1dd314920f67f97011d0  ...
# 1                                        None  ...
# 2                                        None  ...
# 3                                        None  ...
# 4                                        None  ...
#
#                                         gas_metadata gas_offered  gas_spent  \
# 0  {'contract_decimals': 18, 'contract_name': 'Et...       84929      55815
# 1  {'contract_decimals': 18, 'contract_name': 'Et...     5500000    5264347
# 2  {'contract_decimals': 18, 'contract_name': 'Et...     5500000    5226097
# 3  {'contract_decimals': 18, 'contract_name': 'Et...     5500000    5213387
# 4  {'contract_decimals': 18, 'contract_name': 'Et...     5500000    5244910
#
#     gas_price         fees_paid  gas_quote  pretty_gas_quote  gas_quote_rate  \
# 0  4200000000   234423000000000   0.599307             $0.60     2556.520508
# 1   500000000  2632173500000000   4.722150             $4.72     1794.011719
# 2   700000000  3658267900000000   7.601623             $7.60     2077.929443
# 3   950000000  4952717650000000  14.001496            $14.00     2827.032959
# 4  1200000000  6293892000000000  16.379029            $16.38     2602.368896
#
#                                           log_events  \
# 0  [{'block_signed_at': '2025-06-16T21:15:11Z', '...
# 1  [{'block_signed_at': '2025-04-27T21:09:35Z', '...
# 2  [{'block_signed_at': '2025-03-24T23:27:47Z', '...
# 3  [{'block_signed_at': '2025-02-23T19:08:59Z', '...
# 4  [{'block_signed_at': '2025-02-11T03:05:11Z', '...
#
#                                        wallet
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 1  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 2  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 3  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 4  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
#
# [5 rows x 24 columns]

# %%
# Filtering transactions to include only those related to the wallet addresses we have
wallet_list = wallets_id.iloc[:, 0].tolist()
df = txns[txns['wallet'].isin(wallet_list)]

# %%
df.head()
# Out:
#         block_signed_at  block_height  \
# 0  2025-06-16T21:15:11Z      22719696
# 1  2025-04-27T21:09:35Z      22362988
# 2  2025-03-24T23:27:47Z      22120041
# 3  2025-02-23T19:08:59Z      21911013
# 4  2025-02-11T03:05:11Z      21820480
#
#                                           block_hash  \
# 0  0xff57a0c234e73c4897632e198caa0074e84d16080e0f...
# 1  0xe8a130e1e7110fbdde7dd51e74d940f538057be01240...
# 2  0x893f17102836ef520b5239cf68595b7c02c78e206582...
# 3  0x016232bca14eaedba1297086544e1a24a3868ce8d40b...
# 4  0x385f706cfcfdf648c9196d4120011c354371bd1977db...
#
#                                              tx_hash  tx_offset  successful  \
# 0  0x98703fb4a7c6804d82e98f009ecc0e089abd53de9469...        108        True
# 1  0x0b8e89905717b9babd69aa7db6af0afb83331e9b8041...        131        True
# 2  0x5745f6d2e9397ed8ceb7120f42761e1f04643e132e94...        150        True
# 3  0x35cd404392ac9b7786bee78e4bfb2773cbb576b9c3dc...        107        True
# 4  0x51a4f04abaa498409b72d83b4365440f0738ac5bcca1...        196        True
#
#                                 miner_address  \
# 0  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 1  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 2  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 3  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 4  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
#
#                                  from_address from_address_label  \
# 0  0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc               None
# 1  0xfd0ce77ca6521e3cbbcfb07398cca8ec2648115d               None
# 2  0xc07aff7c831105bacaf2fb4d9506332112eee2a1               None
# 3  0xad38352c725c6768c11a9a71bc7d921a9355d56c               None
# 4  0x1e6971036be043c0e2457fe3f6dbed9f73354c6b               None
#
#                                    to_address  ...  \
# 0  0x13173761e24c3708495b1dd314920f67f97011d0  ...
# 1                                        None  ...
# 2                                        None  ...
# 3                                        None  ...
# 4                                        None  ...
#
#                                         gas_metadata gas_offered  gas_spent  \
# 0  {'contract_decimals': 18, 'contract_name': 'Et...       84929      55815
# 1  {'contract_decimals': 18, 'contract_name': 'Et...     5500000    5264347
# 2  {'contract_decimals': 18, 'contract_name': 'Et...     5500000    5226097
# 3  {'contract_decimals': 18, 'contract_name': 'Et...     5500000    5213387
# 4  {'contract_decimals': 18, 'contract_name': 'Et...     5500000    5244910
#
#     gas_price         fees_paid  gas_quote  pretty_gas_quote  gas_quote_rate  \
# 0  4200000000   234423000000000   0.599307             $0.60     2556.520508
# 1   500000000  2632173500000000   4.722150             $4.72     1794.011719
# 2   700000000  3658267900000000   7.601623             $7.60     2077.929443
# 3   950000000  4952717650000000  14.001496            $14.00     2827.032959
# 4  1200000000  6293892000000000  16.379029            $16.38     2602.368896
#
#                                           log_events  \
# 0  [{'block_signed_at': '2025-06-16T21:15:11Z', '...
# 1  [{'block_signed_at': '2025-04-27T21:09:35Z', '...
# 2  [{'block_signed_at': '2025-03-24T23:27:47Z', '...
# 3  [{'block_signed_at': '2025-02-23T19:08:59Z', '...
# 4  [{'block_signed_at': '2025-02-11T03:05:11Z', '...
#
#                                        wallet
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 1  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 2  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 3  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 4  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (2823, 24)

# %%
df.info
# Out:
# <bound method DataFrame.info of            block_signed_at  block_height  \
# 0     2025-06-16T21:15:11Z      22719696
# 1     2025-04-27T21:09:35Z      22362988
# 2     2025-03-24T23:27:47Z      22120041
# 3     2025-02-23T19:08:59Z      21911013
# 4     2025-02-11T03:05:11Z      21820480
# ...                    ...           ...
# 2818  2020-07-29T06:16:50Z      10552810
# 2819  2020-10-21T18:51:46Z      11101237
# 2820  2020-10-21T18:51:31Z      11101235
# 2821  2020-10-21T11:57:13Z      11099370
# 2822  2020-10-21T11:56:05Z      11099365
#
#                                              block_hash  \
# 0     0xff57a0c234e73c4897632e198caa0074e84d16080e0f...
# 1     0xe8a130e1e7110fbdde7dd51e74d940f538057be01240...
# 2     0x893f17102836ef520b5239cf68595b7c02c78e206582...
# 3     0x016232bca14eaedba1297086544e1a24a3868ce8d40b...
# 4     0x385f706cfcfdf648c9196d4120011c354371bd1977db...
# ...                                                 ...
# 2818  0xaddfaf8d626c475d73f6c7f1e1cb248634595c089356...
# 2819  0xff19e5498ca75ca9170f6ef489d8b8ca6716a6a60b70...
# 2820  0x14382455c69542f79d9541f6528d661efb67fbe7a78c...
# 2821  0x057fa26377a5d0bb608d04789d6728a038c9d186477b...
# 2822  0x08fa7d902261df4a83ace02adbc7f4c9b8aa667c0303...
#
#                                                 tx_hash  tx_offset  \
# 0     0x98703fb4a7c6804d82e98f009ecc0e089abd53de9469...        108
# 1     0x0b8e89905717b9babd69aa7db6af0afb83331e9b8041...        131
# 2     0x5745f6d2e9397ed8ceb7120f42761e1f04643e132e94...        150
# 3     0x35cd404392ac9b7786bee78e4bfb2773cbb576b9c3dc...        107
# 4     0x51a4f04abaa498409b72d83b4365440f0738ac5bcca1...        196
# ...                                                 ...        ...
# 2818  0x55030001bba1945f08497ff31ea3e836ba48b68b4726...        198
# 2819  0xe76b49f4a25d49d8e5279e905ca683488f1a21313e57...         50
# 2820  0x5a10a092184342b7e2132f7a60868a735c78b85445ed...        142
# 2821  0xf2135f7e2a3490c5706f36def69926a5b3ae71140bab...        159
# 2822  0x9c2708de3fa45580cb33d08d144b3888b4f360f416f0...         54
#
#       successful                               miner_address  \
# 0           True  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 1           True  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 2           True  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 3           True  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 4           True  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# ...          ...                                         ...
# 2818        True  0x5a0b54d5dc17e0aadc383d2db43b0a0d3e029c4c
# 2819        True  0xea674fdde714fd979de3edf0f56aa9716b898ec8
# 2820        True  0x5a0b54d5dc17e0aadc383d2db43b0a0d3e029c4c
# 2821        True  0x45ddbabcf2cce1aadbd04f5b8745579f3aa2949c
# 2822        True  0x5a0b54d5dc17e0aadc383d2db43b0a0d3e029c4c
#
#                                     from_address from_address_label  \
# 0     0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc               None
# 1     0xfd0ce77ca6521e3cbbcfb07398cca8ec2648115d               None
# 2     0xc07aff7c831105bacaf2fb4d9506332112eee2a1               None
# 3     0xad38352c725c6768c11a9a71bc7d921a9355d56c               None
# 4     0x1e6971036be043c0e2457fe3f6dbed9f73354c6b               None
# ...                                          ...                ...
# 2818  0xfdcab1b4e6292ddd540a3c535f36d32d879aa78a               None
# 2819  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac               None
# 2820  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac               None
# 2821  0x73008d40648d3ccd191d9af6889159c15089095d               None
# 2822  0x9c88429c3f1e701cfe5fe4c8536f90440fac6c47               None
#
#                                       to_address  ...  \
# 0     0x13173761e24c3708495b1dd314920f67f97011d0  ...
# 1                                           None  ...
# 2                                           None  ...
# 3                                           None  ...
# 4                                           None  ...
# ...                                          ...  ...
# 2818  0x1c647c67c1aad0ebff25500f3b3084d3d2872eba  ...
# 2819  0x39aa39c021dfbae8fac545936693ac917d5e7563  ...
# 2820  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  ...
# 2821  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  ...
# 2822  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac  ...
#
#                                            gas_metadata gas_offered  \
# 0     {'contract_decimals': 18, 'contract_name': 'Et...       84929
# 1     {'contract_decimals': 18, 'contract_name': 'Et...     5500000
# 2     {'contract_decimals': 18, 'contract_name': 'Et...     5500000
# 3     {'contract_decimals': 18, 'contract_name': 'Et...     5500000
# 4     {'contract_decimals': 18, 'contract_name': 'Et...     5500000
# ...                                                 ...         ...
# 2818  {'contract_decimals': 18, 'contract_name': 'Et...     2100000
# 2819  {'contract_decimals': 18, 'contract_name': 'Et...      247777
# 2820  {'contract_decimals': 18, 'contract_name': 'Et...       75247
# 2821  {'contract_decimals': 18, 'contract_name': 'Et...      200000
# 2822  {'contract_decimals': 18, 'contract_name': 'Et...       21000
#
#       gas_spent    gas_price          fees_paid  gas_quote  pretty_gas_quote  \
# 0         55815   4200000000    234423000000000   0.599307             $0.60
# 1       5264347    500000000   2632173500000000   4.722150             $4.72
# 2       5226097    700000000   3658267900000000   7.601623             $7.60
# 3       5213387    950000000   4952717650000000  14.001496            $14.00
# 4       5244910   1200000000   6293892000000000  16.379029            $16.38
# ...         ...          ...                ...        ...               ...
# 2818     535112  54000000000  28896048000000000   9.177600             $9.18
# 2819     202784  47000000000   9530848000000000   3.722806             $3.72
# 2820      49811  47000000000   2341117000000000   0.914454             $0.91
# 2821      42369  48000000000   2033712000000000   0.794380             $0.79
# 2822      21000  48000000000   1008000000000000   0.393731             $0.39
#
#       gas_quote_rate                                         log_events  \
# 0        2556.520508  [{'block_signed_at': '2025-06-16T21:15:11Z', '...
# 1        1794.011719  [{'block_signed_at': '2025-04-27T21:09:35Z', '...
# 2        2077.929443  [{'block_signed_at': '2025-03-24T23:27:47Z', '...
# 3        2827.032959  [{'block_signed_at': '2025-02-23T19:08:59Z', '...
# 4        2602.368896  [{'block_signed_at': '2025-02-11T03:05:11Z', '...
# ...              ...                                                ...
# 2818      317.607452  [{'block_signed_at': '2020-07-29T06:16:50Z', '...
# 2819      390.605957  [{'block_signed_at': '2020-10-21T18:51:46Z', '...
# 2820      390.605957  [{'block_signed_at': '2020-10-21T18:51:31Z', '...
# 2821      390.605957  [{'block_signed_at': '2020-10-21T11:57:13Z', '...
# 2822      390.605957                                                 []
#
#                                           wallet
# 0     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 1     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 2     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 3     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 4     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# ...                                          ...
# 2818  0xf80a8b9cfff0febf49914c269fb8aead4a22f847
# 2819  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# 2820  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# 2821  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# 2822  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
#
# [2823 rows x 24 columns]>

# %% [markdown]
# From the above data info:
# - The 'block_signed_at column' is in text format, but it contains dates. We need to convert it to datetime to work with date-related features.
# - The value column is also in text format. Since it shows the transaction amount, we convert it to float to do calculations.
# - The gas_spent column is in integer format. We convert it to float to keep all numeric columns consistent.

# %%
# Convert to datetime
df['block_signed_at'] = pd.to_datetime(df['block_signed_at'])

# Convert to float
df['value'] = df['value'].astype(float)
df['gas_spent'] = df['gas_spent'].astype(float)

# %%
# Display all columns
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#             block_signed_at  block_height  \
# 0 2025-06-16 21:15:11+00:00      22719696
# 1 2025-04-27 21:09:35+00:00      22362988
# 2 2025-03-24 23:27:47+00:00      22120041
# 3 2025-02-23 19:08:59+00:00      21911013
# 4 2025-02-11 03:05:11+00:00      21820480
#
#                                           block_hash  \
# 0  0xff57a0c234e73c4897632e198caa0074e84d16080e0f...
# 1  0xe8a130e1e7110fbdde7dd51e74d940f538057be01240...
# 2  0x893f17102836ef520b5239cf68595b7c02c78e206582...
# 3  0x016232bca14eaedba1297086544e1a24a3868ce8d40b...
# 4  0x385f706cfcfdf648c9196d4120011c354371bd1977db...
#
#                                              tx_hash  tx_offset  successful  \
# 0  0x98703fb4a7c6804d82e98f009ecc0e089abd53de9469...        108        True
# 1  0x0b8e89905717b9babd69aa7db6af0afb83331e9b8041...        131        True
# 2  0x5745f6d2e9397ed8ceb7120f42761e1f04643e132e94...        150        True
# 3  0x35cd404392ac9b7786bee78e4bfb2773cbb576b9c3dc...        107        True
# 4  0x51a4f04abaa498409b72d83b4365440f0738ac5bcca1...        196        True
#
#                                 miner_address  \
# 0  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 1  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 2  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 3  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 4  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
#
#                                  from_address from_address_label  \
# 0  0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc               None
# 1  0xfd0ce77ca6521e3cbbcfb07398cca8ec2648115d               None
# 2  0xc07aff7c831105bacaf2fb4d9506332112eee2a1               None
# 3  0xad38352c725c6768c11a9a71bc7d921a9355d56c               None
# 4  0x1e6971036be043c0e2457fe3f6dbed9f73354c6b               None
#
#                                    to_address to_address_label  value  \
# 0  0x13173761e24c3708495b1dd314920f67f97011d0             None    0.0
# 1                                        None             None    0.0
# 2                                        None             None    0.0
# 3                                        None             None    0.0
# 4                                        None             None    0.0
#
#    value_quote pretty_value_quote  \
# 0          0.0              $0.00
# 1          0.0              $0.00
# 2          0.0              $0.00
# 3          0.0              $0.00
# 4          0.0              $0.00
#
#                                         gas_metadata  gas_offered  gas_spent  \
# 0  {'contract_decimals': 18, 'contract_name': 'Et...        84929    55815.0
# 1  {'contract_decimals': 18, 'contract_name': 'Et...      5500000  5264347.0
# 2  {'contract_decimals': 18, 'contract_name': 'Et...      5500000  5226097.0
# 3  {'contract_decimals': 18, 'contract_name': 'Et...      5500000  5213387.0
# 4  {'contract_decimals': 18, 'contract_name': 'Et...      5500000  5244910.0
#
#     gas_price         fees_paid  gas_quote pretty_gas_quote  gas_quote_rate  \
# 0  4200000000   234423000000000   0.599307            $0.60     2556.520508
# 1   500000000  2632173500000000   4.722150            $4.72     1794.011719
# 2   700000000  3658267900000000   7.601623            $7.60     2077.929443
# 3   950000000  4952717650000000  14.001496           $14.00     2827.032959
# 4  1200000000  6293892000000000  16.379029           $16.38     2602.368896
#
#                                           log_events  \
# 0  [{'block_signed_at': '2025-06-16T21:15:11Z', '...
# 1  [{'block_signed_at': '2025-04-27T21:09:35Z', '...
# 2  [{'block_signed_at': '2025-03-24T23:27:47Z', '...
# 3  [{'block_signed_at': '2025-02-23T19:08:59Z', '...
# 4  [{'block_signed_at': '2025-02-11T03:05:11Z', '...
#
#                                        wallet
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 1  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 2  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 3  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 4  0x0039f22efb07a647557c7c5d17854cfd6d489ef3

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# The following features were selected as risk indicators:
# - **txn_count**: Higher transaction count may indicate more activity or less dormant wallets.
# - **total_value_sent / received**: Helps understand the volume of funds handled.
# - **active_days**: Measures consistent engagement over time.
# - **duration_days**: Long activity duration may correlate with more reliable wallet behavior.
# - **avg_txn_value**: Captures transaction size patterns, useful for outlier detection.

# %%
# Grouping by wallet and computing features
features = df.groupby('wallet').agg(
    txn_count=('tx_hash', 'count'),
    total_value_sent=('value', lambda x: x[df['from_address'] == df['wallet']].sum()),
    total_value_received=('value', lambda x: x[df['to_address'] == df['wallet']].sum()),
    total_gas_spent=('gas_spent', 'sum'),
    avg_txn_value=('value', 'mean'),
    active_days=('block_signed_at', lambda x: x.dt.date.nunique()),
    first_txn_date=('block_signed_at', 'min'),
    last_txn_date=('block_signed_at', 'max'),
).reset_index()

# Finding Duration
features['duration_days'] = (features['last_txn_date'] - features['first_txn_date']).dt.days

# %%
features.head()
# Out:
#                                        wallet  txn_count  total_value_sent  \
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3        100      5.225464e+19
# 1  0x06b51c6882b27cb05e712185531c1f74996dd988          5      5.701850e+15
# 2  0x0795732aacc448030ef374374eaae57d2965c16c          4      0.000000e+00
# 3  0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9         80      1.351075e+20
# 4  0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae          5      7.404691e+15
#
#    total_value_received  total_gas_spent  avg_txn_value  active_days  \
# 0          0.000000e+00      235826553.0   5.225464e+17           77
# 1          1.860000e+16         308732.0   4.860370e+15            1
# 2          1.860000e+16         290793.0   4.650000e+15            1
# 3          6.667600e+19      132280277.0   2.523044e+18           57
# 4          1.860000e+16         308720.0   5.200938e+15            2
#
#              first_txn_date             last_txn_date  duration_days
# 0 2023-04-14 19:48:35+00:00 2025-06-16 21:15:11+00:00            794
# 1 2020-10-16 00:12:29+00:00 2020-10-16 00:19:32+00:00              0
# 2 2020-11-25 12:40:49+00:00 2020-11-25 13:13:37+00:00              0
# 3 2019-07-28 05:10:56+00:00 2025-03-25 19:18:59+00:00           2067
# 4 2020-10-21 12:37:23+00:00 2020-12-24 09:47:49+00:00             63

# %% [markdown]
# ### Data Preprocessing

# %%
# Feature Scaling(MinMax Scaling)
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(features[['txn_count', 'total_value_sent', 'total_value_received',
                                                 'total_gas_spent', 'avg_txn_value', 'active_days', 'duration_days']])

# %%
scaled_features
# Out:
# array([[1.00000000e+00, 7.60203724e-02, 0.00000000e+00, 7.02143178e-01,
#         3.33275660e-02, 1.00000000e+00, 2.77428372e-01],
#        [2.06185567e-02, 8.29508632e-06, 4.53503072e-05, 3.26095268e-04,
#         3.09990266e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.72639030e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00],
#        [7.93814433e-01, 1.96555212e-01, 1.62568660e-01, 3.93586717e-01,
#         1.60917581e-01, 7.36842105e-01, 7.22222222e-01],
#        [2.06185567e-02, 1.07723898e-05, 4.53503072e-05, 3.26059509e-04,
#         3.31711417e-04, 1.31578947e-02, 2.20125786e-02],
#        [3.09278351e-02, 6.90825612e-04, 1.18502830e-03, 4.72684972e-04,
#         1.02140785e-02, 2.63157895e-02, 2.43885395e-01],
#        [3.09278351e-02, 1.51491741e-05, 4.53503072e-05, 8.08375485e-04,
#         3.08406109e-04, 0.00000000e+00, 0.00000000e+00],
#        [4.12371134e-02, 2.28004112e-05, 4.53503072e-05, 1.17731560e-03,
#         3.12267036e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.03092784e-02, 0.00000000e+00, 3.90110169e-05, 3.47529613e-04,
#         2.55116599e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 1.95055085e-02, 9.67941982e-02,
#         5.10233199e-03, 1.44736842e-01, 5.21663173e-01],
#        [3.09278351e-02, 0.00000000e+00, 9.42652460e-06, 5.07448363e-04,
#         4.10971582e-05, 1.31578947e-02, 7.33752621e-03],
#        [2.88659794e-01, 1.43073816e-04, 1.04798269e-04, 1.18831295e-01,
#         2.90766353e-04, 2.50000000e-01, 7.42487771e-01],
#        [2.06185567e-02, 1.38729323e-05, 4.53503072e-05, 3.26095268e-04,
#         3.58897164e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.08413822e-03, 1.73916701e-03, 3.16785378e-02,
#         9.30228079e-04, 3.68421053e-01, 5.27952481e-01],
#        [0.00000000e+00, 1.91030786e-05, 3.90110169e-05, 0.00000000e+00,
#         6.19317087e-04, 1.31578947e-02, 0.00000000e+00],
#        [7.52577320e-01, 0.00000000e+00, 1.50891814e-03, 1.55607893e-01,
#         5.19354052e-04, 3.81578947e-01, 6.21942697e-01],
#        [1.95876289e-01, 2.84697562e-04, 5.84394981e-04, 4.06229563e-03,
#         1.26218527e-03, 5.26315789e-02, 5.62543676e-02],
#        [4.12371134e-02, 1.72006785e-05, 8.77747881e-05, 3.29884496e-03,
#         4.35733207e-04, 2.63157895e-02, 1.67714885e-01],
#        [2.06185567e-02, 1.83799115e-05, 4.53503072e-05, 3.26059509e-04,
#         3.98414636e-04, 1.31578947e-02, 2.79524808e-03],
#        [1.03092784e-02, 0.00000000e+00, 3.90110169e-05, 2.63437132e-04,
#         2.55116599e-04, 0.00000000e+00, 0.00000000e+00],
#        [2.06185567e-02, 2.14463427e-05, 4.53503072e-05, 3.26095268e-04,
#         4.25301294e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 8.60029719e-02, 3.23889931e-02, 6.30546347e-02,
#         4.61764159e-02, 4.60526316e-01, 6.99510832e-01],
#        [1.00000000e+00, 1.47098002e-01, 1.66754257e-01, 6.96454709e-02,
#         1.08108490e-01, 6.71052632e-01, 9.08455625e-02],
#        [1.03092784e-02, 0.00000000e+00, 3.90110169e-05, 2.63437132e-04,
#         2.55116599e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.63517589e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00],
#        [2.06185567e-02, 0.00000000e+00, 4.53503072e-05, 3.45074184e-04,
#         2.37258437e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.20555072e-02, 3.01520180e-03, 1.22603182e-01,
#         6.07390059e-03, 5.00000000e-01, 6.63522013e-01],
#        [1.00000000e+00, 7.03217987e-03, 8.97116570e-03, 6.82574235e-02,
#         5.79725576e-03, 3.42105263e-01, 5.60796646e-01],
#        [1.75257732e-01, 1.25538848e-03, 2.61704534e-03, 1.68655399e-02,
#         6.17471893e-03, 5.26315789e-02, 5.42976939e-01],
#        [1.03092784e-02, 6.09345430e-06, 3.90110169e-05, 1.79720116e-04,
#         3.21901329e-04, 1.31578947e-02, 7.89657582e-02],
#        [1.00000000e+00, 1.14588949e-02, 5.59034058e-03, 7.75840694e-02,
#         6.62786803e-03, 4.73684211e-01, 6.10412299e-01],
#        [2.06185567e-02, 7.35515063e-06, 4.53503072e-05, 4.19344950e-04,
#         3.01748852e-04, 1.31578947e-02, 2.44584207e-03],
#        [2.06185567e-02, 9.00799079e-06, 3.90110169e-05, 4.10107293e-04,
#         2.83075899e-04, 1.31578947e-02, 5.66037736e-02],
#        [3.09278351e-02, 0.00000000e+00, 4.53503072e-05, 4.83612227e-04,
#         1.97715364e-04, 2.63157895e-02, 6.53389238e-02],
#        [4.12371134e-01, 2.24147365e-04, 5.87155547e-04, 6.28199148e-03,
#         5.85715083e-04, 1.97368421e-01, 3.68623340e-01],
#        [4.12371134e-02, 0.00000000e+00, 0.00000000e+00, 2.02370554e-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.06185567e-02, 1.49388659e-05, 4.53503072e-05, 3.35216710e-04,
#         3.68243336e-04, 1.31578947e-02, 1.36268344e-02],
#        [5.15463918e-02, 1.67519773e-05, 4.53503072e-05, 2.87279287e-02,
#         2.40088006e-04, 5.26315789e-02, 5.40181691e-01],
#        [8.24742268e-02, 2.62403773e-04, 4.85422300e-04, 7.10682787e-04,
#         2.20015825e-03, 5.26315789e-02, 4.07058001e-01],
#        [2.06185567e-02, 1.43377739e-05, 4.53503072e-05, 3.26095268e-04,
#         3.62972924e-04, 1.31578947e-02, 5.24109015e-02],
#        [5.36082474e-01, 8.00347437e-04, 1.50137354e-03, 1.17981823e-01,
#         1.35201876e-03, 2.76315789e-01, 5.27603075e-01],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.72639030e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.64433149e-02, 1.47673290e-02, 2.51768391e-02,
#         1.10716993e-02, 5.39473684e-01, 2.38294899e-01],
#        [6.90721649e-01, 1.00000000e+00, 1.00000000e+00, 3.66521096e-01,
#         1.00000000e+00, 7.36842105e-01, 8.86443047e-01],
#        [1.23711340e-01, 1.38881224e-03, 2.36766639e-03, 2.72480202e-03,
#         8.18802393e-03, 1.05263158e-01, 4.63661775e-01],
#        [2.06185567e-02, 1.71369790e-05, 4.53503072e-05, 3.26059509e-04,
#         3.87516527e-04, 1.31578947e-02, 6.63871419e-03],
#        [1.34020619e-01, 2.73558849e-05, 1.35047656e-04, 1.94617477e-03,
#         2.95745197e-04, 3.94736842e-02, 1.74703005e-03],
#        [2.06185567e-02, 1.86008602e-05, 4.53503072e-05, 4.10223509e-04,
#         4.00351928e-04, 1.31578947e-02, 1.36268344e-02],
#        [1.00000000e+00, 5.07763493e-03, 5.30134559e-03, 6.73611949e-02,
#         3.61279885e-03, 4.34210526e-01, 6.37316562e-01],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.72639030e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 3.56767271e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00],
#        [6.18556701e-02, 0.00000000e+00, 2.43818856e-02, 3.16251859e-02,
#         7.08657220e-02, 7.89473684e-02, 6.10761705e-01],
#        [8.24742268e-02, 9.60342577e-06, 8.22866695e-05, 1.00186269e-03,
#         2.33955096e-04, 6.57894737e-02, 3.73864430e-02],
#        [4.12371134e-02, 1.60119412e-05, 4.53503072e-05, 1.14692371e-03,
#         2.69751519e-04, 2.63157895e-02, 3.49406010e-04],
#        [1.03092784e-02, 1.79125703e-05, 4.53503072e-05, 3.73150703e-04,
#         4.92896200e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.63517589e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.23711340e-01, 5.02974487e-03, 1.21909428e-03, 1.77888765e-02,
#         1.68263429e-02, 9.21052632e-02, 8.12019567e-01],
#        [1.03092784e-02, 0.00000000e+00, 3.90110169e-05, 2.63437132e-04,
#         2.55116599e-04, 0.00000000e+00, 0.00000000e+00],
#        [4.12371134e-02, 2.06224482e-05, 4.53503072e-05, 1.23616276e-02,
#         2.98626669e-04, 2.63157895e-02, 4.49685535e-01],
#        [2.16494845e-01, 1.90613815e-03, 3.21720810e-03, 1.87199251e-02,
#         6.95520058e-03, 1.57894737e-01, 5.68134172e-01],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.72639030e-04,
#         2.96573047e-04, 1.31578947e-02, 3.49406010e-04],
#        [2.06185567e-02, 2.18491520e-05, 4.53503072e-05, 4.10223509e-04,
#         4.28833152e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.44329897e-01, 8.62415648e-05, 2.53730239e-04, 2.44217738e-03,
#         6.12825758e-04, 1.31578947e-02, 1.20545073e-01],
#        [2.06185567e-02, 9.02654056e-06, 4.53503072e-05, 3.26095268e-04,
#         3.16403702e-04, 1.31578947e-02, 4.25576520e-01],
#        [3.09278351e-01, 3.88444785e-04, 4.97049071e-04, 2.14984754e-02,
#         9.10047137e-04, 1.18421053e-01, 4.84626136e-01],
#        [1.23711340e-01, 3.42058686e-04, 7.01783813e-04, 2.21451084e-03,
#         2.22356741e-03, 5.26315789e-02, 6.98812020e-03],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.63517589e-04,
#         2.96573047e-04, 1.31578947e-02, 6.98812020e-04],
#        [2.06185567e-02, 2.59700352e-06, 4.53503072e-05, 8.36913887e-04,
#         2.60029124e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 8.52906695e-02, 1.24348603e-01, 1.17200336e-02,
#         6.99193173e-02, 2.36842105e-01, 8.38574423e-03],
#        [0.00000000e+00, 2.16163429e-05, 4.53503072e-05, 8.04570166e-08,
#         7.11319778e-04, 1.31578947e-02, 1.04821803e-03],
#        [9.27835052e-02, 4.10391039e-05, 1.25718829e-04, 7.11657718e-02,
#         4.23981032e-04, 6.57894737e-02, 6.41509434e-01],
#        [1.03092784e-02, 1.77740249e-05, 4.53503072e-05, 5.41407184e-04,
#         4.91377731e-04, 0.00000000e+00, 0.00000000e+00],
#        [5.87628866e-01, 1.17887719e-02, 1.46208519e-02, 1.10531283e-02,
#         1.49880287e-02, 1.57894737e-01, 1.00000000e+00],
#        [4.53608247e-01, 0.00000000e+00, 0.00000000e+00, 8.93352726e-02,
#         0.00000000e+00, 1.57894737e-01, 1.71208945e-02],
#        [1.03092784e-02, 0.00000000e+00, 1.07280297e-03, 1.58770420e-02,
#         7.01570648e-03, 2.63157895e-02, 7.10342418e-01],
#        [1.00000000e+00, 1.16393342e-02, 9.75275423e-03, 4.87275918e-01,
#         7.85797933e-03, 7.23684211e-01, 2.71837876e-01],
#        [8.24742268e-02, 3.78249593e-05, 1.24817650e-04, 3.93128181e-03,
#         4.47571807e-04, 5.26315789e-02, 2.78825996e-01],
#        [5.15463918e-02, 9.98796085e-06, 4.53503072e-05, 1.59222946e-03,
#         2.03020934e-04, 2.63157895e-02, 1.04821803e-03],
#        [2.06185567e-02, 4.82883123e-06, 4.53503072e-05, 7.91565928e-04,
#         2.79597928e-04, 2.63157895e-02, 1.85185185e-01],
#        [8.24742268e-02, 2.84019109e-05, 1.03375830e-04, 1.34670146e-03,
#         3.59026953e-04, 2.63157895e-02, 9.67854647e-02],
#        [1.00000000e+00, 7.27403064e-01, 4.87637712e-13, 1.00000000e+00,
#         3.18895749e-01, 5.39473684e-01, 6.00978337e-02],
#        [9.27835052e-02, 9.59249087e-05, 2.46962412e-04, 1.35915949e-02,
#         8.88793588e-04, 2.63157895e-02, 3.65828092e-01],
#        [9.48453608e-01, 1.56020241e-02, 2.59438245e-02, 2.87957838e-02,
#         1.43436516e-02, 3.68421053e-01, 5.30048917e-01],
#        [1.00000000e+00, 5.12900343e-02, 3.09912654e-02, 2.52991159e-02,
#         3.05925334e-02, 4.73684211e-01, 9.57372467e-02],
#        [2.06185567e-02, 7.23430440e-06, 4.53503072e-05, 8.46035328e-04,
#         3.00689265e-04, 1.31578947e-02, 4.54227813e-03],
#        [2.06185567e-02, 1.52407672e-05, 4.53503072e-05, 4.10187750e-04,
#         3.70890425e-04, 0.00000000e+00, 0.00000000e+00],
#        [3.09278351e-02, 3.95678171e-06, 4.53503072e-05, 3.88672948e-04,
#         2.26626453e-04, 0.00000000e+00, 0.00000000e+00],
#        [2.06185567e-02, 2.09794038e-05, 4.53503072e-05, 3.26095268e-04,
#         4.21207145e-04, 1.31578947e-02, 2.09643606e-03],
#        [3.09278351e-02, 8.33195184e-06, 4.53503072e-05, 1.16505038e-03,
#         2.58594588e-04, 0.00000000e+00, 0.00000000e+00],
#        [5.15463918e-02, 3.16900928e-05, 8.58670762e-05, 5.14555400e-04,
#         4.54431266e-04, 3.94736842e-02, 1.04821803e-02],
#        [1.00000000e+00, 5.63889490e-03, 2.19946405e-03, 6.19049963e-02,
#         3.04745389e-03, 2.10526316e-01, 9.34311670e-01],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.72639030e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00],
#        [9.27835052e-02, 1.05055888e-04, 2.45870348e-04, 1.97235310e-03,
#         9.19771775e-04, 3.94736842e-02, 5.13626834e-02],
#        [5.15463918e-02, 3.31153802e-05, 1.80299436e-04, 1.05796805e-03,
#         7.71017010e-04, 2.63157895e-02, 1.67714885e-01],
#        [2.06185567e-02, 1.83146416e-06, 1.58525168e-05, 3.19250462e-04,
#         9.89937359e-05, 2.63157895e-02, 2.77428372e-01],
#        [7.52577320e-01, 4.97545800e-03, 6.66178989e-03, 1.74480248e-01,
#         5.16299321e-03, 3.28947368e-01, 6.34521314e-01],
#        [1.00000000e+00, 2.62974130e-01, 1.70673199e-08, 5.15573896e-01,
#         1.39843648e-01, 4.47368421e-01, 7.68693222e-02],
#        [1.03092784e-02, 0.00000000e+00, 3.90110169e-05, 2.63437132e-04,
#         2.55116599e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.54639175e-01, 0.00000000e+00, 0.00000000e+00, 2.60539725e-02,
#         0.00000000e+00, 5.26315789e-02, 1.53738644e-02],
#        [1.03092784e-02, 0.00000000e+00, 3.90110169e-05, 2.72522815e-04,
#         2.55116599e-04, 1.31578947e-02, 2.44584207e-03],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 2.63517589e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.03092784e-01, 0.00000000e+00, 9.77723096e-04, 2.03515100e-02,
#         1.96736055e-03, 5.26315789e-02, 5.58700210e-01],
#        [1.03092784e-02, 0.00000000e+00, 4.53503072e-05, 3.47645829e-04,
#         2.96573047e-04, 0.00000000e+00, 0.00000000e+00]])

# %%
# Converting to DataFrame
features_scaled = pd.DataFrame(scaled_features,columns=[
    'txn_count', 'total_value_sent', 'total_value_received',
    'total_gas_spent', 'avg_txn_value', 'active_days', 'duration_days'
])

# %% [markdown]
# ### Risk Scoring Method
#
# - All numeric features were normalized using **MinMaxScaler** to bring them into a comparable range (0–1).
# - Each normalized feature was assigned **equal weight (0.2)**.
# - Final score = Weighted sum × 1000 to scale into 0–1000 range.

# %%
# Assign weights based on feature importance.
features['credit_score'] = (
    features_scaled['txn_count'] * 0.2 +
    features_scaled['total_value_sent'] * 0.2 +
    features_scaled['total_value_received'] * 0.2 +
    features_scaled['active_days'] * 0.2 +
    features_scaled['duration_days'] * 0.2
) * 1000

# %%
# Saving final scores
features[['wallet', 'credit_score']].to_csv('wallet_credit_scores.csv', index=False)

# %%
# Loading wallet scores
wallet_scores = pd.read_csv('wallet_credit_scores.csv')
wallet_scores.head()
# Out:
#                                        wallet  credit_score
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3    470.689749
# 1  0x06b51c6882b27cb05e712185531c1f74996dd988      4.134440
# 2  0x0795732aacc448030ef374374eaae57d2965c16c      2.070926
# 3  0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9    522.400526
# 4  0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae     11.169031

# %%
# Displaying top 10 wallets
top_wallets = features.sort_values(by='credit_score', ascending=False).head(10)
print(top_wallets[['wallet', 'credit_score']])
# Out:
#                                         wallet  credit_score
# 43  0x623af911f493747c216ad389c7805a37019c662d    862.801360
# 3   0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9    522.400526
# 0   0x0039f22efb07a647557c7c5d17854cfd6d489ef3    470.689749
# 80  0xbd4a00764217c13a246f86db58d74541a0c3972a    465.394916
# 21  0x330513970efd9e8dd606275fb4c50378989b3204    455.685822
# 26  0x427f2ac5fdf4245e027d767e7c3ac272a1f40a65    435.718544
# 90  0xdde73df7bd4d704a89ad8421402701b3a460c6e9    430.535269
# 30  0x4d997c89bc659a3e8452038a8101161e7e7e53a7    420.229149
# 48  0x70d8e4ab175dfe0eab4e9a7f33e0a2d19f44001e    416.381214
# 22  0x3361bea43c2f5f963f81ac70f64e6fba1f1d2a97    415.150091

# %% [markdown]
# ### Final Deliverables
#
# - `wallet_credit_scores.csv`: A file containing wallet IDs and their corresponding risk scores between 0–1000.
# - Risk scoring is based on wallet-level transaction behavior including transaction count, gas used, value transferred, and activity duration.
